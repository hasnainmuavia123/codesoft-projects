# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings

# Ignore all warning messages
warnings.filterwarnings("ignore")

# %%
datacd=pd.read_csv('C:\\Users\\Dell\\Desktop\\Data Science\\creditcard.csv')

# %%
datacd.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
datacd.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 195823  131234.0 -0.257777  1.103222 -0.514092 -0.796538  0.673856 -0.445949
# 86214    61140.0  0.765943 -1.512445 -0.052582 -0.320421 -1.410605 -0.972158
# 149436   91230.0  0.243458  1.607334  0.604257  4.491495  1.422615  0.856081
# 182545  125447.0  1.816429  0.146354  0.046576  3.598831 -0.119489  0.764143
# 80102    58337.0 -1.611454  1.857307 -0.464249  0.576393 -0.371490  0.104362
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 195823  0.739306  0.253325 -0.293416  ... -0.260008 -0.674737  0.031350
# 86214   0.025307 -0.291435 -0.822342  ... -0.404333 -1.497084 -0.095714
# 149436  1.706574 -0.731723 -0.713783  ... -0.153006  0.293057 -0.124659
# 182545 -0.673691  0.375930 -0.534457  ...  0.235474  0.539597  0.240714
# 80102  -0.301572  1.297371 -1.052339  ...  0.231216  0.329221 -0.126432
#
# ...

# %%
datacd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
datacd.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
sns.set(style="whitegrid")
sns.displot(datacd["V1"],kde=True,color="orange")
plt.show()

# %%
sns.scatterplot(x="V1",y=datacd.index,data=datacd)
plt.show()

# %%
sns.displot(datacd["V2"],kde=True,color="orange")
plt.show()

# %%
sns.scatterplot(x="V2",y=datacd.index,data=datacd)
plt.show()

# %%
sns.displot(datacd["V3"],kde=True,color="orange")
plt.show()

# %%
sns.scatterplot(x="V3",y=datacd.index,data=datacd)
plt.show()

# %%
correlation_matrix = datacd.corr()
plt.figure(figsize=(26, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(data=datacd)
plt.figure(figsize=(26, 8))
plt.show()

# %%
datacd["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(datacd["Class"])
plt.show()

# %%
# 0 --> Normal transction
# 1 --> frudulant transction

# %%
legit=datacd[datacd.Class==0]
frud=datacd[datacd.Class==1]

# %%
print(legit.shape)
print(frud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
frud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
datacd.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#unbalanced dataset we perforn under sampling tech

# %%
legit_sample=legit.sample(n=492)

# %%
new_dataset=pd.concat([legit_sample,frud])

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 173151  121367.0 -2.809972  0.204018  0.223911  1.813867  2.737275  1.800899
# 12799    22464.0 -1.310910  1.321889  1.777237  0.710339  0.016335  0.008036
# 117394   74661.0  1.174914 -1.722884  0.964054 -1.116507 -1.934355  0.299910
# 116157   74166.0  1.171163 -0.425147  0.712189  0.444927 -0.440770  1.111524
# 130286   79324.0 -0.952267  1.253593  0.161556  0.613289  0.265068  0.412444
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 173151  0.304131  0.636624 -1.366581  ...  0.361486  1.055485 -0.886858
# 12799   0.207087  0.491241  0.176057  ...  0.013033  0.063060 -0.260441
# 117394 -1.404033  0.120209 -1.303205  ... -0.239004 -0.338477 -0.092999
# 116157 -0.945006  0.530904  1.012615  ... -0.107680 -0.202165 -0.077472
# 130286 -0.445287 -0.336278 -0.686197  ...  0.599190 -0.742683 -0.054220
#
# ...

# %%
new_dataset["Class"].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
sns.countplot(new_dataset["Class"])
plt.show()

# %%
x=new_dataset.drop(["Class"],axis=1)
y=new_dataset["Class"]

# %%
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 173151  121367.0 -2.809972  0.204018  0.223911  1.813867  2.737275  1.800899
# 12799    22464.0 -1.310910  1.321889  1.777237  0.710339  0.016335  0.008036
# 117394   74661.0  1.174914 -1.722884  0.964054 -1.116507 -1.934355  0.299910
# 116157   74166.0  1.171163 -0.425147  0.712189  0.444927 -0.440770  1.111524
# 130286   79324.0 -0.952267  1.253593  0.161556  0.613289  0.265068  0.412444
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y
# Out:
# 173151    0
# 12799     0
# 117394    0
# 116157    0
# 130286    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_train,y_train)*100
# Out:
# 95.04447268106735

# %%
model.score(x_test,y_test)*100
# Out:
# 93.90862944162437

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# %%
y_pred = model.predict(x_test)
y_pred = model.predict(x_test)

# Calculate precision
precision = precision_score(y_test, y_pred)
print(f'Precision: {precision}')

# Calculate recall
recall = recall_score(y_test, y_pred)
print(f'Recall: {recall}')

# Calculate F1 score
f1 = f1_score(y_test, y_pred)
print(f'F1 Score: {f1}')

# Print detailed classification report
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Precision: 0.9479166666666666
# Recall: 0.9285714285714286
# F1 Score: 0.9381443298969072
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        99
#            1       0.95      0.93      0.94        98
#
#     accuracy                           0.94       197
#    macro avg       0.94      0.94      0.94       197
# weighted avg       0.94      0.94      0.94       197
